# %%
file_1 = open("watermelon.fsa")
complete_genome = file_1.read()

#rough coding
#############
#length of the whole file
#print(str(len(complete_genome)))

#length of string to be deleted
#to_be_deleted = ">watermelon [organism=Citrullus lanatus] [common=watermelon] [cultivar=Florida giant] [molecule=DNA] [location=mitochondrion] [topology=circular] Citrullus lanatus mitochondrion, complete genome"
#print(str(len(to_be_deleted)))

#print(complete_genome[195:379432])

#write watermelon genome only to watermelon_genome.fsa file
file_2 = open("watermelon_genome.fsa", "w").write(complete_genome[195:379432])

file_3 = open("watermelon_genome.fsa")
watermelon_genome = file_3.read()

#to check the content of watermelon_genome.fsa
#print(watermelon_genome)

#to count the length of the strings, watermelon_genome length is 379237
length_watermelon_genome = len(watermelon_genome)
print("Length of the genome is: " + str(length_watermelon_genome))

#EXON
#####

exon_1 = watermelon_genome[0:726]
exon_2 = watermelon_genome[1693:2551]
exon_3 = watermelon_genome[29746:30628]
exon_4 = watermelon_genome[32108:32225]
exon_5 = watermelon_genome[32635:32914]
exon_6 = watermelon_genome[32932:33006]
exon_7 = watermelon_genome[34731:36349]
exon_8 = watermelon_genome[36320:36731]
exon_9 = watermelon_genome[42043:42817]
exon_10 = watermelon_genome[43946:44231]
exon_11 = watermelon_genome[52679:53747]
exon_12 = watermelon_genome[54399:55017]
exon_13 = watermelon_genome[67124:67604]
exon_14 = watermelon_genome[68217:69015]
exon_15 = watermelon_genome[68942:69350]
exon_16 = watermelon_genome[70072:70261]
exon_17 = watermelon_genome[71738:72310]
exon_18 = watermelon_genome[74592:74753]
exon_19 = watermelon_genome[86723:87080]
exon_20 = watermelon_genome[87128:87500]
exon_21 = watermelon_genome[88707:89407]
exon_22 = watermelon_genome[91441:91524]
exon_23 = watermelon_genome[96686:97073]
exon_24 = watermelon_genome[112517:114047]
exon_25 = watermelon_genome[174365:174826]
exon_26 = watermelon_genome[176229:176744]
exon_27 = watermelon_genome[179828:180251]
exon_28 = watermelon_genome[182961:183050]
exon_29 = watermelon_genome[185934:186193]
exon_30 = watermelon_genome[187055:189062]
exon_31 = watermelon_genome[189674:189733]
exon_32 = watermelon_genome[204423:206157]
exon_33 = watermelon_genome[222045:222579]
exon_34 = watermelon_genome[230172:230793]
exon_35 = watermelon_genome[240231:240516]
exon_36 = watermelon_genome[241645:242218]
exon_37 = watermelon_genome[242699:242924]
exon_38 = watermelon_genome[243220:243450]
exon_39 = watermelon_genome[244298:245514]
exon_40 = watermelon_genome[265952:266502]
exon_41 = watermelon_genome[267463:268230]
exon_42 = watermelon_genome[272806:272828]
exon_43 = watermelon_genome[274339:274897]
exon_44 = watermelon_genome[275819:276992]
exon_45 = watermelon_genome[279454:279901]
exon_46 = watermelon_genome[311223:312072]
exon_47 = watermelon_genome[330833:331184]
exon_48 = watermelon_genome[332074:332155]
exon_49 = watermelon_genome[333595:333787]
exon_50 = watermelon_genome[335931:336084]
exon_51 = watermelon_genome[337300:337692]
exon_52 = watermelon_genome[344865:345260]
exon_53 = watermelon_genome[346364:346502]
exon_54 = watermelon_genome[348454:348716]
exon_55 = watermelon_genome[350530:350774]
exon_56 = watermelon_genome[351835:352302]
exon_57 = watermelon_genome[353940:354009]
exon_58 = watermelon_genome[354915:355058]
exon_59 = watermelon_genome[362963:363662]
exon_60 = watermelon_genome[365317:365914]
exon_61 = watermelon_genome[366129:366432]
exon_62 = watermelon_genome[376484:376763]
exon_63 = watermelon_genome[377833:378083]
exon_64 = watermelon_genome[378928:379011]

#total_length_exon = len(exon_1) + len(exon_2) + len(exon_3) + len(exon_4) + len(exon_5) + len(exon_6) + len(exon_7) + len(exon_8) + len(exon_9) + len(exon_10) + len(exon_11) + len(exon_12) + len(exon_13) + len(exon_14) + len(exon_15) + len(exon_16) + len(exon_17) + len(exon_18) + len(exon_19) + len(exon_20) + len(exon_21) + len(exon_22) + len(exon_23) + len(exon_24) + len(exon_25) + len(exon_26) + len(exon_27) + len(exon_28) + len(exon_29) + len(exon_30) + len(exon_31) + len(exon_32) + len(exon_33) + len(exon_34) + len(exon_35) + len(exon_36) + len(exon_37) + len(exon_38) + len(exon_39) + len(exon_40) + len(exon_41) + len(exon_42) + len(exon_43) + len(exon_44) + len(exon_45) + len(exon_46) + len(exon_47) + len(exon_48) + len(exon_49) + len(exon_50) + len(exon_51) + len(exon_52) + len(exon_53) + len(exon_54) + len(exon_55) + len(exon_56) + len(exon_57) + len(exon_58) + len(exon_59) + len(exon_60) + len(exon_61) + len(exon_62) + len(exon_63) + len(exon_64)
#print(total_length_exon)

total_exon = exon_1 + exon_2 + exon_3 + exon_4 + exon_5 + exon_6 + exon_7 + exon_8 + exon_9 + exon_10 + exon_11 + exon_12 + exon_13 + exon_14 + exon_15 + exon_16 + exon_17 + exon_18 + exon_19 + exon_20 + exon_21 + exon_22 + exon_23 + exon_24 + exon_25 + exon_26 + exon_27 + exon_28 + exon_29 + exon_30 + exon_31 + exon_32 + exon_33 + exon_34 + exon_35 + exon_36 + exon_37 + exon_38 + exon_39 + exon_40 + exon_41 + exon_42 + exon_43 + exon_44 + exon_45 + exon_46 + exon_47 + exon_48 + exon_49 + exon_50 + exon_51 + exon_52 + exon_53 + exon_54 + exon_55 + exon_56 + exon_57 + exon_58 + exon_59 + exon_60 + exon_61 + exon_62 + exon_63 + exon_64
print("\nSum of exon: " + str(len(total_exon)))
print("Sum of GC in exon: " + str((total_exon.count('G')) + (total_exon.count('C'))))
#print(total_exon)

#intron
######

intron_1 = watermelon_genome[726:1693]
intron_2 = watermelon_genome[30628:32108]
intron_3 = watermelon_genome[33006:34731]
intron_4 = watermelon_genome[70261:71738]
intron_5 = watermelon_genome[72310:74592]
intron_6 = watermelon_genome[174826:176229]
intron_7 = watermelon_genome[176744:179828]
intron_8 = watermelon_genome[180251:182961]
intron_9 = watermelon_genome[186193:189674]
intron_10 = watermelon_genome[243450:244298]
intron_11 = watermelon_genome[266502:267463]
intron_12 = watermelon_genome[332155:333595]
intron_13 = watermelon_genome[336084:337300]
intron_14 = watermelon_genome[345260:346364]
intron_15 = watermelon_genome[348716:350530]
intron_16 = watermelon_genome[350774:351835]
intron_17 = watermelon_genome[352302:353940]
intron_18 = watermelon_genome[354009:354915]
intron_19 = watermelon_genome[378083:378928]

total_intron = intron_1 + intron_2 + intron_3 + intron_4 + intron_5 + intron_6 + intron_7 + intron_8 + intron_9 + intron_10 + intron_11 + intron_12 + intron_13 + intron_14 + intron_15 + intron_16 + intron_17 + intron_18 + intron_19
print("\nSum of intron: " + str(len(total_intron)))
print("Sum of GC in intron: " + str((total_intron.count('G')) + (total_intron.count('C'))))
#print(total_intron)


#misc_feature
######

misc_1 = watermelon_genome[4257:7876]
misc_2 = watermelon_genome[5345:5418]
misc_3 = watermelon_genome[11969:12424]
misc_4 = watermelon_genome[21731:21962]
misc_5 = watermelon_genome[21962:22398]
misc_6 = watermelon_genome[56332:56435]
misc_7 = watermelon_genome[95665:95778]
misc_8 = watermelon_genome[109438:109546]
misc_9 = watermelon_genome[110135:110264]
misc_10 = watermelon_genome[110905:111090]
misc_11 = watermelon_genome[132693:132946]
misc_12 = watermelon_genome[139516:139550]
misc_13 = watermelon_genome[39715:143326]
misc_14 = watermelon_genome[140378:140451]
misc_15 = watermelon_genome[152691:154871]
misc_16 = watermelon_genome[53987:154060]
misc_17 = watermelon_genome[170165:171491]
misc_18 = watermelon_genome[170501:170575]
misc_19 = watermelon_genome[183915:185776]
misc_20 = watermelon_genome[220861:221131]
misc_21 = watermelon_genome[223353:223536]
misc_22 = watermelon_genome[223761:224140]
misc_23 = watermelon_genome[224183:224763]
misc_24 = watermelon_genome[224256:224330]
misc_25 = watermelon_genome[224475:224550]
misc_26 = watermelon_genome[247268:248777]
misc_27 = watermelon_genome[274064:274235]
misc_28 = watermelon_genome[311009:311217]
misc_29 = watermelon_genome[321309:322800]
misc_30 = watermelon_genome[322700:322774]
misc_31 = watermelon_genome[322810:326632]
misc_32 = watermelon_genome[330721:330778]
misc_33 = watermelon_genome[335197:335317]
misc_34 = watermelon_genome[338629:338776]
misc_35 = watermelon_genome[343911:343965]
misc_36 = watermelon_genome[362837:362923]
misc_37 = watermelon_genome[366674:366719]

total_misc = misc_1 + misc_2 + misc_3 + misc_4 + misc_5 + misc_6 + misc_7 +misc_8 + misc_9 + misc_10 + misc_11 + misc_12 + misc_13 + misc_14 + misc_15 + misc_16 + misc_17 + misc_18 + misc_19 + misc_20 + misc_21 + misc_22 + misc_23 + misc_24 + misc_25 + misc_26 + misc_27 + misc_28 + misc_29 + misc_30 + misc_31 + misc_32 + misc_33 + misc_34 + misc_35 + misc_36 + misc_37
print("\nSum of misc feature: " + str(len(total_misc)))
print("Sum of GC in misc feature: " + str((total_misc.count('G')) + (total_misc.count('C'))))
#print(total_misc)

#rRNA
#####

rRNA_1 = watermelon_genome[148377:51548]
rRNA_2 = watermelon_genome[306499:306618]
rRNA_3 = watermelon_genome[307209:309067]

total_rRNA = rRNA_1 + rRNA_2 + rRNA_3
print("\nSum of rRNA: " + str(len(total_rRNA)))
print("Sum of GC in rRNA: " + str((total_rRNA.count('G')) + (total_rRNA.count('C'))))
#print(total_rRNA)

#repeat region
#####

rregion_1 = watermelon_genome[42841:50127]
rregion_2 = watermelon_genome[234335:241621]
rregion_3 = watermelon_genome[238844:23891]
                              
total_rregion = rregion_1 + rregion_2 + rregion_3
print("\nSum of repeat region: " + str(len(total_rregion)))
print("Sum of GC in repeat region: " + str((total_rregion.count('G')) + (total_rregion.count('C'))))
#print(total_rregion)

#tRNA
######
                              
tRNA_1 = watermelon_genome[44456:44528]
tRNA_2 = watermelon_genome[45546:45618]
tRNA_3 = watermelon_genome[50760:50833]
tRNA_4 = watermelon_genome[75276:75359]
tRNA_5 = watermelon_genome[76360:76432]
tRNA_6 = watermelon_genome[78203:78274]
tRNA_7 = watermelon_genome[121266:121339]
tRNA_8 = watermelon_genome[130200:130272]
tRNA_9 = watermelon_genome[131225:131299]
tRNA_10 = watermelon_genome[151917:151991]
tRNA_11 = watermelon_genome[155600:155681]
tRNA_12 = watermelon_genome[227589:227662]
tRNA_13 = watermelon_genome[238844:238916]
tRNA_14 = watermelon_genome[239934:240006]
tRNA_15 = watermelon_genome[286844:286919]
tRNA_16 = watermelon_genome[287215:287289]
tRNA_17 = watermelon_genome[287652:287740]
tRNA_18 = watermelon_genome[358590:358677]                           

total_tRNA = tRNA_1 + tRNA_2 + tRNA_3 + tRNA_4 + tRNA_5 + tRNA_6 + tRNA_7 + tRNA_8 + tRNA_9 + tRNA_10 + tRNA_11 + tRNA_12 + tRNA_13 + tRNA_14 + tRNA_15 + tRNA_16 + tRNA_17 + tRNA_18                           
print("\nSum of tRNA: " + str(len(total_tRNA)))
print("Sum of GC in tRNA: " + str((total_tRNA.count('G')) + (total_tRNA.count('C'))))
#print(total_tRNA)

exon_percent = (total_exon/length_watermelon_genome)*100
print(str(exon_percent))
# Out:
# Length of the genome is: 379237
#
# Sum of exon: 32442
# Sum of GC in exon: 13990
#
# Sum of intron: 30442
# Sum of GC in intron: 15624
#
# Sum of misc feature: 224282
# Sum of GC in misc feature: 99028
#
# Sum of rRNA: 1977
# Sum of GC in rRNA: 1058
#
# Sum of repeat region: 14572
# Sum of GC in repeat region: 6654
#
# Sum of tRNA: 1358
# Sum of GC in tRNA: 682
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-4f814edf5597> in <module>()
#     228 #print(total_tRNA)
#     229
# --> 230 exon_percent = (total_exon/length_watermelon_genome)*100
#     231 print(str(exon_percent))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
